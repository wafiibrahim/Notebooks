# %%
import pandas as pd

df = pd.read_csv('movies.csv')

df[df['year'] >2000]
# Out:
#                                                    name rating      genre  \
# 3843              Harry Potter and the Sorcerer's Stone     PG  Adventure
# 3844                           The Fast and the Furious  PG-13     Action
# 3845  The Lord of the Rings: The Fellowship of the Ring  PG-13     Action
# 3846                                     Legally Blonde  PG-13     Comedy
# 3847                                     Mulholland Dr.      R      Drama
# ...                                                 ...    ...        ...
# 7663                                       More to Life    NaN      Drama
# 7664                                        Dream Round    NaN     Comedy
# 7665                                      Saving Mbango    NaN      Drama
# 7666                                       It's Just Us    NaN      Drama
# 7667                                          Tee em el    NaN     Horror
#
#       year                           released  score      votes  \
# ...
